# %% [markdown]
# <a href="https://colab.research.google.com/github/jhuma26/Counterfeit-Medicine-Sales-Prediction/blob/main/Churn_Modelling_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
X = df.iloc[:,3:13]
Y = df.iloc[:,13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
#Categorical columns
# Geography, Gender

# %%
geography = pd.get_dummies(X['Geography'],drop_first=True)

# %%
gender = pd.get_dummies(X['Gender'], drop_first = True)

# %%
X=pd.concat([X,geography, gender],axis=1)

# %%
X.drop(['Geography','Gender'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8b126e59603d> in <cell line: 1>()
# ----> 1 X.drop(['Geography','Gender'],axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
X.shape
# Out:
# (10000, 11)

# %% [markdown]
# # Splitting the dataset into train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.09792126, -0.55759842, -1.03635146, ..., -0.56987189,
#         -0.5731713 ,  0.92295821],
#        [-1.12612023,  0.01725942,  0.69700901, ..., -0.56987189,
#         -0.5731713 ,  0.92295821],
#        [-0.62230274,  3.5622161 ,  0.00366482, ..., -0.56987189,
#         -0.5731713 , -1.08347268],
#        ...,
#        [ 0.89943174, -0.36597914,  0.00366482, ..., -0.56987189,
#         -0.5731713 ,  0.92295821],
#        [-0.62230274, -0.07855022,  1.39035319, ..., -0.56987189,
#          1.74467913, -1.08347268],
#        [-0.28299708,  0.87954618, -1.38302356, ...,  1.75478035,
#         -0.5731713 , -1.08347268]])

# %%
x_train.shape
# Out:
# (7000, 11)

# %% [markdown]
# # Create Artificial Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
classifier = Sequential()

# %%
#input layer
classifier.add(Dense(units=11, activation='relu'))

# %%
#1st hidden layer
classifier.add(Dense(units=7, activation='relu'))

# %%
#2nd hidden layer
classifier.add(Dense(units=6, activation='relu'))

# %%
#output layer
classifier.add(Dense(units=1, activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history = classifier.fit(x_train,y_train,validation_split=0.33,batch_size=10, epochs=1000)
# Out:
# Epoch 1/1000
# 469/469 [==============================] - 6s 5ms/step - loss: 0.5153 - accuracy: 0.7985 - val_loss: 0.4729 - val_accuracy: 0.7962
# Epoch 2/1000
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4289 - accuracy: 0.8059 - val_loss: 0.4369 - val_accuracy: 0.8135
# Epoch 3/1000
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3994 - accuracy: 0.8258 - val_loss: 0.4194 - val_accuracy: 0.8170
# Epoch 4/1000
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3809 - accuracy: 0.8362 - val_loss: 0.4035 - val_accuracy: 0.8230
# Epoch 5/1000
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3660 - accuracy: 0.8473 - val_loss: 0.3940 - val_accuracy: 0.8356
# Epoch 6/1000
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3555 - accuracy: 0.8494 - val_loss: 0.3858 - val_accuracy: 0.8364
# Epoch 7/1000
# ...

# %%
pip install keras

# %%
import tensorflow as tf
from tensorflow import keras
earlystopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
model_history = classifier.fit(x_train,y_train,validation_split=0.33,batch_size=10, epochs=1000,callbacks = earlystopping)
# Out:
# Epoch 1/1000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8695 - val_loss: 0.3739 - val_accuracy: 0.8477
# Epoch 2/1000
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3146 - accuracy: 0.8708 - val_loss: 0.3754 - val_accuracy: 0.8468
# Epoch 3/1000
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3149 - accuracy: 0.8695 - val_loss: 0.3728 - val_accuracy: 0.8455
# Epoch 4/1000
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3140 - accuracy: 0.8705 - val_loss: 0.3724 - val_accuracy: 0.8494
# Epoch 5/1000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3145 - accuracy: 0.8725 - val_loss: 0.3740 - val_accuracy: 0.8473
# Epoch 6/1000
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3147 - accuracy: 0.8701 - val_loss: 0.3730 - val_accuracy: 0.8486
# Epoch 7/1000
# ...

# %%
#testing the test data
y_pred = classifier.predict(x_test)
y_pred = (y_pred>=0.5)
# Out:
# 94/94 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[2232,  301],
#        [ 147,  320]])

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
score
# Out:
# 0.8506666666666667
